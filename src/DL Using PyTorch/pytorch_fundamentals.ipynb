# %% [markdown]
# <a href="https://colab.research.google.com/github/gunitk31/artificial-intelligence/blob/main/src/DL%20Using%20PyTorch/pytorch_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.10.0+cpu

# %%
#scalar
scalar=torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
scalar.ndim
# Out:
# 0
